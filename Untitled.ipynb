# sqft_lot            0.015286  0.053080      0.007644 -0.129574  NaN  0.212525
# floors             -0.235836  0.578619     -0.007775 -0.096743  NaN  0.098689
# waterfront          0.080588 -0.026161      0.092885  0.030285  NaN -0.023592
# view                0.276947 -0.053440      0.103917  0.084827  NaN -0.004453
# condition           0.174105 -0.361417     -0.060618  0.003026  NaN -0.096406
# grade               0.168392  0.446963      0.014414 -0.184862  NaN  0.050593
# sqft_above         -0.051943  0.423898      0.023285 -0.261190  NaN  0.149158
# sqft_basement       1.000000 -0.133124      0.071323  0.074845  NaN -0.096471
# yr_built           -0.133124  1.000000     -0.224874 -0.346869  NaN  0.164916
# yr_renovated        0.071323 -0.224874      1.000000  0.064357  NaN -0.014064
# zipcode             0.074845 -0.346869      0.064357  1.000000  NaN -0.194071
# lat                      NaN       NaN           NaN       NaN  NaN       NaN
# long               -0.096471  0.164916     -0.014064 -0.194071  NaN  1.000000
# sqft_living15       0.200355  0.326229     -0.002673 -0.279033  NaN  0.108746
# sqft_lot15          0.017276  0.070958      0.007854 -0.147221  NaN  0.246480
#
#                sqft_living15  sqft_lot15
# price               0.585379    0.082447
# bedrooms            0.391638    0.029244
# bathrooms           0.510049    0.080779
# sqft_living         0.756420    0.183286
# sqft_lot            0.144608    0.718557
# floors              0.296561   -0.013252
# waterfront          0.086463    0.030703
# view                0.280439    0.072575
# condition          -0.092824   -0.003406
# grade               0.713202    0.119248
# sqft_above          0.731870    0.194050
# sqft_basement       0.200355    0.017276
# yr_built            0.326229    0.070958
# yr_renovated       -0.002673    0.007854
# zipcode            -0.279033   -0.147221
# lat                      NaN         NaN
# long                0.108746    0.246480
# sqft_living15       1.000000    0.183192
# sqft_lot15          0.183192    1.000000

# %%
housing.dtypes
# Out:
# price            int64
# bedrooms         int64
# bathrooms        int64
# sqft_living      int64
# sqft_lot         int64
# floors           int64
# waterfront       int64
# view             int64
# condition        int64
# grade            int64
# sqft_above       int64
# sqft_basement    int64
# yr_built         int64
# yr_renovated     int64
# zipcode          int64
# lat              int64
# long             int64
# sqft_living15    int64
# sqft_lot15       int64
# dtype: object

# %%
housing.hist(figsize = (20,20))
# Out:
# array([[<AxesSubplot:title={'center':'price'}>,
#         <AxesSubplot:title={'center':'bedrooms'}>,
#         <AxesSubplot:title={'center':'bathrooms'}>,
#         <AxesSubplot:title={'center':'sqft_living'}>],
#        [<AxesSubplot:title={'center':'sqft_lot'}>,
#         <AxesSubplot:title={'center':'floors'}>,
#         <AxesSubplot:title={'center':'waterfront'}>,
#         <AxesSubplot:title={'center':'view'}>],
#        [<AxesSubplot:title={'center':'condition'}>,
#         <AxesSubplot:title={'center':'grade'}>,
#         <AxesSubplot:title={'center':'sqft_above'}>,
#         <AxesSubplot:title={'center':'sqft_basement'}>],
#        [<AxesSubplot:title={'center':'yr_built'}>,
#         <AxesSubplot:title={'center':'yr_renovated'}>,
#         <AxesSubplot:title={'center':'zipcode'}>,
#         <AxesSubplot:title={'center':'lat'}>],
#        [<AxesSubplot:title={'center':'long'}>,
#         <AxesSubplot:title={'center':'sqft_living15'}>,
#         <AxesSubplot:title={'center':'sqft_lot15'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
x = housing.drop('price',axis = 1)

# %%
y = housing.get('price')

# %%
x.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3          1         1180      5650       1           0     0
# 1         3          2         2570      7242       2           0     0
# 2         2          1          770     10000       1           0     0
# 3         4          3         1960      5000       1           0     0
# 4         3          2         1680      8080       1           0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0          3      7        1180              0      1955             0
# 1          3      7        2170            400      1951          1991
# 2          3      6         770              0      1933             0
# 3          5      7        1050            910      1965             0
# 4          3      8        1680              0      1987             0
#
#    zipcode  lat  long  sqft_living15  sqft_lot15
# 0    98178   47  -122           1340        5650
# 1    98125   47  -122           1690        7639
# 2    98028   47  -122           2720        8062
# 3    98136   47  -122           1360        5000
# 4    98074   47  -122           1800        7503

# %%
y.head()
# Out:
# 0    221900
# 1    538000
# 2    180000
# 3    604000
# 4    510000
# Name: price, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (17290, 18)

# %%
x_test.shape
# Out:
# (4323, 18)

# %%
models = []
# models.append(('LR',LinearRegression()))
models.append(('Ex',ExtraTreesRegressor()))
models.append(('Dt',DecisionTreeRegressor()))
# models.append(('AR',AdaBoostRegressor()))
# models.append(('RR',RandomForestRegressor()))
# models.append(('BR',BaggingRegressor()))
# models.append(('GR',GradientBoostingRegressor()))
models
# Out:
# [('Ex', ExtraTreesRegressor()), ('Dt', DecisionTreeRegressor())]

# %%
results = []
name = []

# %%
for name, model in models:
    model.fit(x_train,y_train)
    results.append(model.score(x_train,y_train))
    results

# %%
print(results)
# Out:
# [0.9992207603679837, 0.9992207609356236]

# %%
for name, model in models:
    model.fit(x_train,y_train)
    
#     obj = model.predict(x_test)
    results.append(model.score(x_test,y_test))
    print(results)
# Out:
# [0.9992207603679837, 0.9992207609356236, 0.755153113167304]
# [0.9992207603679837, 0.9992207609356236, 0.755153113167304, 0.6160055120349928]

# %%
model.predict(x_test)
# Out:
# array([ 359900.,  825000., 1775000., ...,  267000.,  635000.,  338000.])

# %%
y_train_pred = cross_val_score(model,x_test,y_test,cv=3,scoring='accuracy')
y_train_pred
# Out:
# array([0.00624566, 0.00485774, 0.00416378])

# %%
y_test_pred = cross_val_predict(model,x_test,y_test,cv=3)
y_test_pred
# Out:
# array([ 500000.,  902000., 1160000., ...,  309000.,  893880.,  349950.])

# %%
y_pred = model.predict(x_test)
pd.crosstab(y_test,y_pred,rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted  85000.0  92000.0  95000.0  100000.0  102500.0  105000.0  115000.0  \
# True
# 82500            0        0        0         0         0         0         0
# 83000            0        0        0         0         0         0         0
# 89000            0        0        0         0         0         0         0
# 89950            0        1        0         0         0         0         0
# 100000           0        0        1         0         0         0         0
# ...            ...      ...      ...       ...       ...       ...       ...
# 4000000          0        0        0         0         0         0         0
# 4500000          0        0        0         0         0         0         0
# 5350000          0        0        0         0         0         0         0
# 5570000          0        0        0         0         0         0         0
# All              1        2        5         3         1         1         1
#
# Predicted  120000.0  120750.0  121800.0  ...  3100000.0  3120000.0  3204000.0  \
# True                                     ...
# 82500             0         0         0  ...          0          0          0
# 83000             0         0         0  ...          0          0          0
# 89000             0         0         0  ...          0          0          0
# 89950             0         0         0  ...          0          0          0
# 100000            0         0         0  ...          0          0          0
# ...             ...       ...       ...  ...        ...        ...        ...
# 4000000           0         0         0  ...          0          0          0
# 4500000           0         0         0  ...          0          0          0
# 5350000           0         0         0  ...          0          0          0
# 5570000           0         0         0  ...          0          0          0
# All               1         1         1  ...          3          1          1
#
# Predicted  3345000.0  3395000.0  3400000.0  4489000.0  5110800.0  7062500.0  \
# True
# 82500              0          0          0          0          0          0
# 83000              0          0          0          0          0          0
# 89000              0          0          0          0          0          0
# 89950              0          0          0          0          0          0
# 100000             0          0          0          0          0          0
# ...              ...        ...        ...        ...        ...        ...
# 4000000            0          0          0          0          0          0
# 4500000            0          0          0          0          0          0
# 5350000            0          0          0          0          1          0
# 5570000            0          0          0          0          1          0
# All                2          1          3          1          3          1
#
# Predicted   All
# True
# 82500         1
# 83000         1
# 89000         1
# 89950         1
# 100000        2
# ...         ...
# 4000000       1
# 4500000       1
# 5350000       1
# 5570000       1
# All        4323
#
# [1531 rows x 1372 columns]

# %%
mse = mean_squared_error(y_test,y_test_pred)

# %%
mse
# Out:
# 82827527881.28406

# %%
from joblib import load,dump

# %%
dump(model,'housing.joblib')
# Out:
# ['housing.joblib']

# %%
h = x_test.iloc[:5]

# %%
h[:2]
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 735          4          2         2070      8893       2           0     0
# 2830         5          3         2900      6730       1           0     0
#
#       condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 735           4      8        2070              0      1986             0
# 2830          5      8        1830           1070      1977             0
#
#       zipcode  lat  long  sqft_living15  sqft_lot15
# 735     98058   47  -122           2390        7700
# 2830    98115   47  -122           2370        6283

# %%
y_test.head()
# Out:
# 735       365000
# 2830      865000
# 4106     1038000
# 16218    1490000
# 19964     711000
# Name: price, dtype: int64
